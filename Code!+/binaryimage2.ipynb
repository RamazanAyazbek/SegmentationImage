# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('000000.png',0)

# %%
plt.imshow(img)

# %%
# plt.imshow(img)

# %%
# ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)

# %%
plt.subplot(1,1,1),plt.imshow(thresh1,'gray')
# plt.title(titles[i])
plt.xticks([]),plt.yticks([])

plt.show()

# %%
# ret,thresh1 = cv2.threshold(img,255,500,cv2.THRESH_BINARY)

# %%
plt.subplot(1,1,1),plt.imshow(thresh1,'gray')
# plt.title(titles[i])
plt.xticks([]),plt.yticks([])

plt.show()
